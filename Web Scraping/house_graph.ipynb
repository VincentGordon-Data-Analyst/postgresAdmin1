# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('predicting_house_price.csv')
df.head()
# Out:
#    Unnamed: 0               street               city province postal_code  \
# 0           0  #903 -151 AVENUE RD            Toronto  Ontario     M5R 2H7
# 1           1        7575 4TH LINE  Centre Wellington  Ontario     N0B 1S0
# 2           2    388A WHITMORE AVE            Toronto  Ontario     M6E 2N4
# 3           3         332 DURIE ST            Toronto  Ontario     M6S 3G3
# 4           4     71 WALMSLEY BLVD            Toronto  Ontario     M4V 1X7
#
#        style    price  number_of_beds  number_of_baths  extra_space
# 0  Apartment  1955000               2                2            1
# 1   Detached  1799900               5                2            0
# 2    Triplex  1795000               4                2            1
# 3   Detached  1699000               4                2            0
# 4     Duplex  1599000               3                2            0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       614 non-null    int64
#  1   street           614 non-null    object
#  2   city             614 non-null    object
#  3   province         614 non-null    object
#  4   postal_code      614 non-null    object
#  5   style            614 non-null    object
#  6   price            614 non-null    int64
#  7   number_of_beds   614 non-null    int64
#  8   number_of_baths  614 non-null    int64
#  9   extra_space      614 non-null    int64
# dtypes: int64(5), object(5)
# memory usage: 48.1+ KB

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.hist(bins=50, figsize=(10, 8))
plt.show()

# %%
corr_matrix = df.corr()
print(corr_matrix.price.sort_values(ascending=False))
# Out:
# price              1.000000
# number_of_beds     0.184015
# extra_space        0.104424
# number_of_baths         NaN
# Name: price, dtype: float64

# %%
plt.figure(figsize=(20, 15))
correlations = df.corr()
sns.heatmap(correlations, cmap="coolwarm", annot=True)
plt.show()
